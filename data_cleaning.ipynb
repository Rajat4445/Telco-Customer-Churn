# %% [markdown]
# # <center> Data Cleaning and Joining of Telco Customer Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#1 STATUS TABLE

status = pd.read_excel('Status.xlsx')
status.head()
# Out:
#     Status ID Customer ID  Count Quarter  Satisfaction Score Customer Status  \
# 0  SWSORB1252  8779-QRDMV      1      Q3                   3         Churned
# 1  SNAEQA8572  7495-OOKFY      1      Q3                   3         Churned
# 2  LMBQNN3714  1658-BYGOY      1      Q3                   2         Churned
# 3  VRZYZI9978  4598-XLKNJ      1      Q3                   2         Churned
# 4  FDNAKX1688  4846-WHAFZ      1      Q3                   2         Churned
#
#   Churn Label  Churn Value  Churn Score  CLTV   Churn Category  \
# 0         Yes            1           91  5433       Competitor
# 1         Yes            1           69  5302       Competitor
# 2         Yes            1           81  3179       Competitor
# 3         Yes            1           88  5337  Dissatisfaction
# 4         Yes            1           67  2793            Price
#
#                    Churn Reason
# 0  Competitor offered more data
# 1  Competitor made better offer
# 2  Competitor made better offer
# 3     Limited range of services
# 4            Extra data charges

# %%
status.isna().sum()
# Out:
# Status ID                0
# Customer ID              0
# Count                    0
# Quarter                  0
# Satisfaction Score       0
# Customer Status          0
# Churn Label              0
# Churn Value              0
# Churn Score              0
# CLTV                     0
# Churn Category        5174
# Churn Reason          5174
# dtype: int64

# %% [markdown]
# - So, we have missing values in `Churn Category` and `Churn Reason`. Let us look closer into these values.

# %%
status[(status['Churn Category'].isnull())&(status['Churn Reason'].isnull())]
# Out:
#        Status ID Customer ID  Count Quarter  Satisfaction Score  \
# 476   XOZICB8671  3841-NFECX      1      Q3                   4
# 477   SJGVNA3887  4929-XIHVW      1      Q3                   5
# 478   IBNOJY7673  3413-BMNZE      1      Q3                   3
# 479   WGDMSH3435  8012-SOUDQ      1      Q3                   4
# 480   QWAGNG6814  6575-SUVOI      1      Q3                   4
# ...          ...         ...    ...     ...                 ...
# 7038  HNJTLH8249  2569-WGERO      1      Q3                   5
# 7039  SJJDWW6147  6840-RESVB      1      Q3                   3
# 7040  AODCBE7865  2234-XADUH      1      Q3                   4
# 7041  GLQPEW3973  4801-JZAZL      1      Q3                   4
# 7042  KCNRPQ8327  3186-AJIEK      1      Q3                   4
#
#      Customer Status Churn Label  Churn Value  Churn Score  CLTV  \
# 476           Stayed          No            0           38  5309
# 477           Joined          No            0           69  4449
# 478           Joined          No            0           40  3144
# 479           Stayed          No            0           52  2223
# 480           Stayed          No            0           25  3154
# ...              ...         ...          ...          ...   ...
# 7038          Stayed          No            0           45  5306
# 7039          Stayed          No            0           59  2140
# 7040          Stayed          No            0           71  5560
# 7041          Stayed          No            0           59  2793
# 7042          Stayed          No            0           38  5097
#
#      Churn Category Churn Reason
# 476             NaN          NaN
# 477             NaN          NaN
# 478             NaN          NaN
# 479             NaN          NaN
# 480             NaN          NaN
# ...             ...          ...
# 7038            NaN          NaN
# 7039            NaN          NaN
# 7040            NaN          NaN
# 7041            NaN          NaN
# 7042            NaN          NaN
#
# [5174 rows x 12 columns]

# %%
status[(status['Churn Category'].isnull())&(status['Churn Reason'].isnull())]['Churn Label'].value_counts()
# Out:
# No    5174
# Name: Churn Label, dtype: int64

# %% [markdown]
# - `Churn Category` and `Churn Reason` are null for customer who have not churned.
# - Let us fill these missing values with `Not Applicable` to ensure that we know that these values are null because customer did not churn.

# %%
status['Churn Category'] = status['Churn Category'].fillna('Not Applicable')
status['Churn Reason'] = status['Churn Reason'].fillna('Not Applicable')

# %%
status.isna().sum()    # Confirming the changes
# Out:
# Status ID             0
# Customer ID           0
# Count                 0
# Quarter               0
# Satisfaction Score    0
# Customer Status       0
# Churn Label           0
# Churn Value           0
# Churn Score           0
# CLTV                  0
# Churn Category        0
# Churn Reason          0
# dtype: int64

# %%
status.drop(columns='Status ID', inplace=True)

# %% [markdown]
# - `Status` table is free of missing values now.

# %%
#2 POPULATION

population = pd.read_excel('Population.xlsx')
population.head()
# Out:
#    ID  Zip Code  Population
# 0   1     90001       54492
# 1   2     90002       44586
# 2   3     90003       58198
# 3   4     90004       67852
# 4   5     90005       43019

# %%
population.isna().sum()
# Out:
# ID            0
# Zip Code      0
# Population    0
# dtype: int64

# %%
population.dtypes
# Out:
# ID            int64
# Zip Code      int64
# Population    int64
# dtype: object

# %%
population.drop(columns='ID', inplace=True)

# %% [markdown]
# - No treatment required for `Population` table.

# %%
#3 DEMOGRAPHICS

demographics = pd.read_excel('Demographics.xlsx')
demographics.head()
# Out:
#   Customer ID  Count  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV      1    Male   78       No            Yes      No         No
# 1  7495-OOKFY      1  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY      1    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ      1  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ      1  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents
# 0                     0
# 1                     1
# 2                     3
# 3                     1
# 4                     1

# %%
demographics.isna().sum()
# Out:
# Customer ID             0
# Count                   0
# Gender                  0
# Age                     0
# Under 30                0
# Senior Citizen          0
# Married                 0
# Dependents              0
# Number of Dependents    0
# dtype: int64

# %% [markdown]
# - No treatment needed for `Demographics` table.

# %%
#4 LOCATION

location = pd.read_excel('Location.xlsx')
location.head()
# Out:
#   Location ID Customer ID  Count        Country       State         City  \
# 0  OXCZEW7397  8779-QRDMV      1  United States  California  Los Angeles
# 1  FCCECI8494  7495-OOKFY      1  United States  California  Los Angeles
# 2  HEHUQY7254  1658-BYGOY      1  United States  California  Los Angeles
# 3  WIUHRF2613  4598-XLKNJ      1  United States  California    Inglewood
# 4  CFEZBF4415  4846-WHAFZ      1  United States  California     Whittier
#
#    Zip Code                Lat Long   Latitude   Longitude
# 0     90022   34.02381, -118.156582  34.023810 -118.156582
# 1     90063  34.044271, -118.185237  34.044271 -118.185237
# 2     90065  34.108833, -118.229715  34.108833 -118.229715
# 3     90303  33.936291, -118.332639  33.936291 -118.332639
# 4     90602  33.972119, -118.020188  33.972119 -118.020188

# %%
location.isna().sum()
# Out:
# Location ID    0
# Customer ID    0
# Count          0
# Country        0
# State          0
# City           0
# Zip Code       0
# Lat Long       0
# Latitude       0
# Longitude      0
# dtype: int64

# %% [markdown]
# - There are no missing values in `location` table.
# - But columns like `Count`, `Lat Long` (it is available) are not needed, we are going to drop them.

# %%
location.drop(columns=['Count', 'Lat Long', 'Location ID'], inplace=True)

# %%
location.head()      # COnfirming changes
# Out:
#   Customer ID        Country       State         City  Zip Code   Latitude  \
# 0  8779-QRDMV  United States  California  Los Angeles     90022  34.023810
# 1  7495-OOKFY  United States  California  Los Angeles     90063  34.044271
# 2  1658-BYGOY  United States  California  Los Angeles     90065  34.108833
# 3  4598-XLKNJ  United States  California    Inglewood     90303  33.936291
# 4  4846-WHAFZ  United States  California     Whittier     90602  33.972119
#
#     Longitude
# 0 -118.156582
# 1 -118.185237
# 2 -118.229715
# 3 -118.332639
# 4 -118.020188

# %%
#5 SERVICES

services = pd.read_excel('Services.xlsx')
services.head()
# Out:
#       Service ID Customer ID  Count Quarter Referred a Friend  \
# 0  IJKDQVSWH3522  8779-QRDMV      1      Q3                No
# 1  BFKMZJAIE2285  7495-OOKFY      1      Q3               Yes
# 2  EIMVJQBMT7187  1658-BYGOY      1      Q3                No
# 3  EROZQXDUU4979  4598-XLKNJ      1      Q3               Yes
# 4  GEEYSJUHY6991  4846-WHAFZ      1      Q3               Yes
#
#    Number of Referrals  Tenure in Months    Offer Phone Service  \
# 0                    0                 1     None            No
# 1                    1                 8  Offer E           Yes
# 2                    0                18  Offer D           Yes
# 3                    1                25  Offer C           Yes
# 4                    1                37  Offer C           Yes
#
#    Avg Monthly Long Distance Charges  ... Unlimited Data        Contract  \
# 0                               0.00  ...             No  Month-to-Month
# 1                              48.85  ...            Yes  Month-to-Month
# 2                              11.33  ...            Yes  Month-to-Month
# 3                              19.76  ...            Yes  Month-to-Month
# 4                               6.33  ...            Yes  Month-to-Month
#
#   Paperless Billing   Payment Method Monthly Charge Total Charges  \
# 0               Yes  Bank Withdrawal          39.65         39.65
# 1               Yes      Credit Card          80.65        633.30
# 2               Yes  Bank Withdrawal          95.45       1752.55
# 3               Yes  Bank Withdrawal          98.50       2514.50
# 4               Yes  Bank Withdrawal          76.50       2868.15
#
#   Total Refunds Total Extra Data Charges Total Long Distance Charges  \
# 0          0.00                       20                        0.00
# 1          0.00                        0                      390.80
# 2         45.61                        0                      203.94
# 3         13.43                        0                      494.00
# 4          0.00                        0                      234.21
#
#   Total Revenue
# 0         59.65
# 1       1024.10
# 2       1910.88
# 3       2995.07
# 4       3102.36
#
# [5 rows x 31 columns]

# %%
services.isna().sum()
# Out:
# Service ID                           0
# Customer ID                          0
# Count                                0
# Quarter                              0
# Referred a Friend                    0
# Number of Referrals                  0
# Tenure in Months                     0
# Offer                                0
# Phone Service                        0
# Avg Monthly Long Distance Charges    0
# Multiple Lines                       0
# Internet Service                     0
# Internet Type                        0
# Avg Monthly GB Download              0
# Online Security                      0
# Online Backup                        0
# Device Protection Plan               0
# Premium Tech Support                 0
# Streaming TV                         0
# Streaming Movies                     0
# Streaming Music                      0
# Unlimited Data                       0
# Contract                             0
# Paperless Billing                    0
# Payment Method                       0
# Monthly Charge                       0
# Total Charges                        0
# Total Refunds                        0
# Total Extra Data Charges             0
# Total Long Distance Charges          0
# Total Revenue                        0
# dtype: int64

# %% [markdown]
# - There are no missing values in `Services` table.
# - But we will have to drop some columns which do not add any value.

# %%
services.drop(columns=['Count', 'Service ID'], inplace=True)

# %%
services.head()
# Out:
#   Customer ID Quarter Referred a Friend  Number of Referrals  \
# 0  8779-QRDMV      Q3                No                    0
# 1  7495-OOKFY      Q3               Yes                    1
# 2  1658-BYGOY      Q3                No                    0
# 3  4598-XLKNJ      Q3               Yes                    1
# 4  4846-WHAFZ      Q3               Yes                    1
#
#    Tenure in Months    Offer Phone Service  Avg Monthly Long Distance Charges  \
# 0                 1     None            No                               0.00
# 1                 8  Offer E           Yes                              48.85
# 2                18  Offer D           Yes                              11.33
# 3                25  Offer C           Yes                              19.76
# 4                37  Offer C           Yes                               6.33
#
#   Multiple Lines Internet Service  ... Unlimited Data        Contract  \
# 0             No              Yes  ...             No  Month-to-Month
# 1            Yes              Yes  ...            Yes  Month-to-Month
# 2            Yes              Yes  ...            Yes  Month-to-Month
# 3             No              Yes  ...            Yes  Month-to-Month
# 4            Yes              Yes  ...            Yes  Month-to-Month
#
#   Paperless Billing   Payment Method Monthly Charge Total Charges  \
# 0               Yes  Bank Withdrawal          39.65         39.65
# 1               Yes      Credit Card          80.65        633.30
# 2               Yes  Bank Withdrawal          95.45       1752.55
# 3               Yes  Bank Withdrawal          98.50       2514.50
# 4               Yes  Bank Withdrawal          76.50       2868.15
#
#   Total Refunds Total Extra Data Charges Total Long Distance Charges  \
# 0          0.00                       20                        0.00
# 1          0.00                        0                      390.80
# 2         45.61                        0                      203.94
# 3         13.43                        0                      494.00
# 4          0.00                        0                      234.21
#
#   Total Revenue
# 0         59.65
# 1       1024.10
# 2       1910.88
# 3       2995.07
# 4       3102.36
#
# [5 rows x 29 columns]

# %% [markdown]
# ## <center>Joining all tables to make a final table

# %%
table = status.merge(services, on='Customer ID', how='left', suffixes=('_status', '_services')) \
        .merge(demographics, on='Customer ID', how='left') \
        .merge(location, on='Customer ID', how='left') \
        .merge(population, on='Zip Code', how='left')

# %%
table.head()
# Out:
#   Customer ID  Count_x Quarter_status  Satisfaction Score Customer Status  \
# 0  8779-QRDMV        1             Q3                   3         Churned
# 1  7495-OOKFY        1             Q3                   3         Churned
# 2  1658-BYGOY        1             Q3                   2         Churned
# 3  4598-XLKNJ        1             Q3                   2         Churned
# 4  4846-WHAFZ        1             Q3                   2         Churned
#
#   Churn Label  Churn Value  Churn Score  CLTV   Churn Category  ... Married  \
# 0         Yes            1           91  5433       Competitor  ...      No
# 1         Yes            1           69  5302       Competitor  ...     Yes
# 2         Yes            1           81  3179       Competitor  ...      No
# 3         Yes            1           88  5337  Dissatisfaction  ...     Yes
# 4         Yes            1           67  2793            Price  ...     Yes
#
#   Dependents Number of Dependents        Country       State         City  \
# 0         No                    0  United States  California  Los Angeles
# 1        Yes                    1  United States  California  Los Angeles
# 2        Yes                    3  United States  California  Los Angeles
# 3        Yes                    1  United States  California    Inglewood
# 4        Yes                    1  United States  California     Whittier
#
#   Zip Code   Latitude   Longitude Population
# 0    90022  34.023810 -118.156582      68701
# 1    90063  34.044271 -118.185237      55668
# 2    90065  34.108833 -118.229715      47534
# 3    90303  33.936291 -118.332639      27778
# 4    90602  33.972119 -118.020188      26265
#
# [5 rows x 54 columns]

# %%
col_order = ['Customer ID', 'Country', 'State', 'City', 'Zip Code', 'Latitude', 'Longitude', 'Population',
                  'Age', 'Gender', 'Under 30', 'Senior Citizen', 'Married', 'Dependents', 'Number of Dependents', 
                  'Referred a Friend', 'Number of Referrals','Tenure in Months','Offer','Phone Service','Avg Monthly Long Distance Charges',
                     'Multiple Lines', 'Internet Service', 'Internet Type','Avg Monthly GB Download','Online Security','Online Backup',
                 'Device Protection Plan','Premium Tech Support','Streaming TV','Streaming Movies','Streaming Music',
                 'Unlimited Data','Contract','Paperless Billing','Payment Method','Monthly Charge','Total Charges','Total Refunds',
             'Total Extra Data Charges','Total Long Distance Charges','Total Revenue', 'Quarter_status','Satisfaction Score',
             'Customer Status','Churn Label','Churn Value','Churn Score','CLTV','Churn Category','Churn Reason','Quarter_services']

final_data= table[col_order]

# %%
#final_data.to_csv('telco_final_data.csv', index=False)

# %%
df=pd.read_csv('telco_final_data.csv')
df.head()
# Out:
#   Customer ID        Country       State         City  Zip Code   Latitude  \
# 0  8779-QRDMV  United States  California  Los Angeles     90022  34.023810
# 1  7495-OOKFY  United States  California  Los Angeles     90063  34.044271
# 2  1658-BYGOY  United States  California  Los Angeles     90065  34.108833
# 3  4598-XLKNJ  United States  California    Inglewood     90303  33.936291
# 4  4846-WHAFZ  United States  California     Whittier     90602  33.972119
#
#     Longitude  Population  Age  Gender  ... Quarter_status Satisfaction Score  \
# 0 -118.156582       68701   78    Male  ...             Q3                  3
# 1 -118.185237       55668   74  Female  ...             Q3                  3
# 2 -118.229715       47534   71    Male  ...             Q3                  2
# 3 -118.332639       27778   78  Female  ...             Q3                  2
# 4 -118.020188       26265   80  Female  ...             Q3                  2
#
#   Customer Status Churn Label  Churn Value Churn Score  CLTV   Churn Category  \
# 0         Churned         Yes            1          91  5433       Competitor
# 1         Churned         Yes            1          69  5302       Competitor
# 2         Churned         Yes            1          81  3179       Competitor
# 3         Churned         Yes            1          88  5337  Dissatisfaction
# 4         Churned         Yes            1          67  2793            Price
#
#                    Churn Reason Quarter_services
# 0  Competitor offered more data               Q3
# 1  Competitor made better offer               Q3
# 2  Competitor made better offer               Q3
# 3     Limited range of services               Q3
# 4            Extra data charges               Q3
#
# [5 rows x 52 columns]
